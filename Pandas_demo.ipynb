# %%
import pandas as pd
#https://www.machinelearningplus.com/python/101-pandas-exercises-python/
#https://www.w3resource.com/python-exercises/pandas/index.php
#https://github.com/CoreyMSchafer/code_snippets/tree/master/Python/Pandas

# %%
df = pd.read_csv('survey_results_public.csv', index_col= 'Respondent')

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
schema_df = pd.read_csv('survey_results_schema.csv', index_col = 'Column')

# %%
schema_df
# Out:
#                                                          QuestionText
# Column
# Respondent          Randomized respondent ID number (not in order ...
# MainBranch          Which of the following options best describes ...
# Hobbyist                                      Do you code as a hobby?
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.loc['WebframeWorkedWith','QuestionText']
# Out:
# 'Which web frameworks have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the framework and want to continue to do so, please check both boxes in that row.)'

# %%
schema_df.sort_index(inplace = True)
schema_df
# Out:
#                                                          QuestionText
# Column
# Age                 What is your age (in years)? If you prefer not...
# Age1stCode          At what age did you write your first line of c...
# CompFreq             Is that compensation weekly, monthly, or yearly?
# CompTotal           What is your current total compensation (salar...
# ConvertedComp       Salary converted to annual USD salaries using ...
# ...                                                               ...
# WebframeWorkedWith  Which web frameworks have you done extensive d...
# WelcomeChange       Compared to last year, how welcome do you feel...
# WorkWeekHrs         On average, how many hours per week do you wor...
# YearsCode           Including any education, how many years have y...
# YearsCodePro        NOT including education, how many years have y...
#
# [61 rows x 1 columns]

# %%
schema_df.head()
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# CompFreq        Is that compensation weekly, monthly, or yearly?
# CompTotal      What is your current total compensation (salar...
# ConvertedComp  Salary converted to annual USD salaries using ...

# %%
df.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df.loc[0:2,'Hobbyist':'Employment']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-a9b1ca3544a2> in <module>()
# ----> 1 df.loc[0:2,'Hobbyist':'Employment']
#
# ...

# %%
high_salary = (df['ConvertedComp']>70000)

# %%
df.loc[high_salary, ['Country', 'WebframeWorkedWith', 'ConvertedComp']]
# Out:
#                    Country                     WebframeWorkedWith  \
# Respondent
# 8            United States                                  Flask
# 16          United Kingdom                        jQuery;React.js
# 17           United States  ASP.NET;Gatsby;jQuery;React.js;Vue.js
# 18           United States                                    NaN
# 19           United States        Angular;Angular.js;ASP.NET Core
# ...                    ...                                    ...
# 65586        United States                                    NaN
# 65589        United States                                    NaN
# 65602        United States                                    NaN
# 65604        United States                                    NaN
# 65617              Germany                                    NaN
#
#             ConvertedComp
# Respondent
# 8                116000.0
# 16               108576.0
# 17                79000.0
# 18              1260000.0
# ...

# %%
countries = ['United States', 'India', 'Canada', 'United Kingdom', 'Germany', 'Canada']
filt2 = df['Country'].isin(countries)

# %%
df.loc[filt2, 'Country']
# Out:
# Respondent
# 1               Germany
# 2        United Kingdom
# 5         United States
# 6               Germany
# 7                 India
#               ...
# 62834            Canada
# 62954             India
# 63077     United States
# 64236             India
# 64858     United States
# Name: Country, Length: 30849, dtype: object

# %%
filt3 = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt3, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
filt3

# %%
df.rename(columns={'ConvertedComp':'SalaryUSD'}, inplace = True)

# %%
df['SalaryUSD']
# Out:
# Respondent
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
#          ..
# 64858   NaN
# 64867   NaN
# 64898   NaN
# 64925   NaN
# 65112   NaN
# Name: SalaryUSD, Length: 64461, dtype: float64

# %%
df['Hobbyist']
# Out:
# Respondent
# 1        Yes
# 2         No
# 3        Yes
# 4        Yes
# 5        Yes
#         ...
# 64858    Yes
# 64867    Yes
# 64898    Yes
# 64925    Yes
# 65112    Yes
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'].map({'Yes':'True','No':'False'})
# Out:
# Respondent
# 1         True
# 2        False
# 3         True
# 4         True
# 5         True
#          ...
# 64858     True
# 64867     True
# 64898     True
# 64925     True
# 65112     True
# Name: Hobbyist, Length: 64461, dtype: object

# %%
df['Hobbyist'] = df['Hobbyist'].map({'Yes':'True','No':'False'})

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession     True   NaN
# 2                              I am a developer by profession    False   NaN
# 3                                 I code primarily as a hobby     True   NaN
# 4                              I am a developer by profession     True  25.0
# 5           I used to be a developer by profession, but no...     True  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN     True   NaN
# 64867                                                     NaN     True   NaN
# 64898                                                     NaN     True   NaN
# 64925                                                     NaN     True   NaN
# 65112                                                     NaN     True   NaN
#
# ...

# %%
df.sort_values(by=['Country','ConvertedComp'], ascending = [True, False], inplace=True)

# %%
df[['Country','ConvertedComp']].head(50)
# Out:
#                 Country  ConvertedComp
# Respondent
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 62788       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# 63848       Afghanistan        23328.0
# 9839        Afghanistan        23328.0
# 51862       Afghanistan        20950.0
# 51509       Afghanistan        20220.0
# 44484       Afghanistan        18660.0
# 15422       Afghanistan        18000.0
# 2932        Afghanistan        16335.0
# 26540       Afghanistan        13992.0
# 57269       Afghanistan        10884.0
# 26775       Afghanistan         8016.0
# 30568       Afghanistan         5448.0
# 30522       Afghanistan         4668.0
# 28811       Afghanistan         4509.0
# 34969       Afghanistan         4356.0
# 26857       Afghanistan         2328.0
# 33878       Afghanistan         1860.0
# 35753       Afghanistan          780.0
# 18049       Afghanistan          109.0
# ...

# %%
df['ConvertedComp'].nlargest(10) #top results for the column
# Out:
# Respondent
# 54263    2000000.0
# 5725     2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 1793     2000000.0
# 3072     2000000.0
# 3045     2000000.0
# 1413     2000000.0
# 3261     2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df.nlargest(10, 'ConvertedComp')
# Out:
#                                 MainBranch Hobbyist   Age  \
# Respondent
# 54263       I am a developer by profession      Yes  29.0
# 5725        I am a developer by profession       No  26.0
# 43430       I am a developer by profession      Yes  33.0
# 59279       I am a developer by profession      Yes   NaN
# 46711       I am a developer by profession      Yes   NaN
# 1793        I am a developer by profession      Yes  27.0
# 3072        I am a developer by profession      Yes  32.0
# 3045        I am a developer by profession      Yes  35.0
# 1413        I am a developer by profession      Yes  25.0
# 3261        I am a developer by profession      Yes  34.0
#
#                       Age1stCode CompFreq     CompTotal  ConvertedComp  \
# Respondent
# 54263                         10   Weekly  7.000000e+04      2000000.0
# 5725                          14  Monthly  1.800000e+05      2000000.0
# 43430                         17  Monthly  1.710000e+05      2000000.0
# ...

# %%
df = pd.read_csv('survey_results_public.csv', index_col= 'Respondent')

# %%
df['ConvertedComp'].median()
# Out:
# 54049.0

# %%
df.median()
# Out:
# Age                 29.0
# CompTotal        63000.0
# ConvertedComp    54049.0
# WorkWeekHrs         40.0
# dtype: float64

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].count()
# Out:
# 64416

# %%
df['Country'].value_counts()
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Liechtenstein         1
# Lesotho               1
# Gabon                 1
# Saint Lucia           1
# Nauru                 1
# Name: Country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['Country']) #create an object for Country
country_grp

# %%
country_grp.get_group('India')#Groups by Country names using the country_grp DataFrame object
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 7                   I am a developer by profession      Yes   NaN         18
# 22                  I am a developer by profession      Yes   NaN         18
# 58                  I am a developer by profession      Yes   NaN         22
# 63          I am a student who is learning to code      Yes  21.0         17
# 149                 I am a developer by profession      Yes  36.0         31
# ...                                            ...      ...   ...        ...
# 54757                                          NaN      Yes   NaN         18
# 55407                                          NaN      Yes   NaN        NaN
# 62464                                          NaN      Yes   NaN        NaN
# 62954                                          NaN      Yes   NaN        NaN
# 64236                                          NaN      Yes   NaN        NaN
#
# ...

# %%
filt=df['Country'] == 'United States'
df[filt]
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 5           I used to be a developer by profession, but no...      Yes  31.0
# 8                              I am a developer by profession      Yes  36.0
# 14                             I am a developer by profession      Yes  27.0
# 17                             I am a developer by profession      Yes  25.0
# 18                             I am a developer by profession      Yes  32.0
# ...                                                       ...      ...   ...
# 58498                                                     NaN      Yes  32.0
# 58896                                                     NaN      Yes  29.0
# 60931                                                     NaN      Yes   NaN
# 63077                                                     NaN      Yes   NaN
# 64858                                                     NaN      Yes   NaN
#
# ...

# %%
country_grp['WebframeWorkedWith'].value_counts(normalize=True).loc['Russian Federation']
# Out:
# WebframeWorkedWith
# jQuery                                  0.063609
# React.js                                0.060651
# Spring                                  0.053254
# Flask                                   0.051775
# Django                                  0.041420
#                                           ...
# jQuery;React.js;Ruby on Rails;Vue.js    0.001479
# jQuery;Ruby on Rails;Vue.js             0.001479
# jQuery;Spring;Symfony                   0.001479
# jQuery;Symfony;Vue.js                   0.001479
# jQuery;Vue.js                           0.001479
# Name: WebframeWorkedWith, Length: 247, dtype: float64

# %%
country_grp['ConvertedComp'].median()
# Out:
# Country
# Afghanistan                             15163.5
# Albania                                 15900.0
# Algeria                                  9432.0
# Andorra                                 88640.0
# Angola                                   5292.0
#                                          ...
# Venezuela, Bolivarian Republic of...     3600.0
# Viet Nam                                10344.0
# Yemen                                   36000.0
# Zambia                                   5452.0
# Zimbabwe                                 7200.0
# Name: ConvertedComp, Length: 183, dtype: float64

# %%
country_grp['ConvertedComp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['ConvertedComp'].agg(['median','mean']).loc['Canada']
# Out:
# median     68068.000000
# mean      115101.775465
# Name: Canada, dtype: float64

# %%
filt = df['Country'] == 'Russian Federation'
df.loc[filt]['WebframeWorkedWith'].str.contains('Angular').sum()
# Out:
# 144

# %%
country_grp['WebframeWorkedWith'].str.contains('Angular').sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-f2ea70859e24> in <module>()
# ----> 1 country_grp['WebframeWorkedWith'].str.contains('Angular').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     702
#     703         raise AttributeError(
# --> 704             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     705         )
#     706
#
# AttributeError: 'SeriesGroupBy' object has no attribute 'str'

# %%
country_grp['WebframeWorkedWith'].apply(lambda x:x.str.contains('Angular').sum())
# Out:
# Country
# Afghanistan                             17
# Albania                                 12
# Algeria                                 11
# Andorra                                  3
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...    20
# Viet Nam                                72
# Yemen                                    1
# Zambia                                   2
# Zimbabwe                                 7
# Name: WebframeWorkedWith, Length: 183, dtype: int64

# %%
country_respondents=df['Country'].value_counts()
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Liechtenstein         1
# Lesotho               1
# Gabon                 1
# Saint Lucia           1
# Nauru                 1
# Name: Country, Length: 183, dtype: int64

# %%
country_uses_Angular = country_grp['WebframeWorkedWith'].apply(lambda x:x.str.contains('Angular').sum())
country_uses_Angular
# Out:
# Country
# Afghanistan                             17
# Albania                                 12
# Algeria                                 11
# Andorra                                  3
# Angola                                   1
#                                         ..
# Venezuela, Bolivarian Republic of...    20
# Viet Nam                                72
# Yemen                                    1
# Zambia                                   2
# Zimbabwe                                 7
# Name: WebframeWorkedWith, Length: 183, dtype: int64

# %%
Angular_df = pd.concat([country_respondents, country_uses_Angular], axis='columns', sort=False)
Angular_df
# Out:
#                 Country  WebframeWorkedWith
# United States     12469                2453
# India              8403                2052
# United Kingdom     3896                 649
# Germany            3890                 797
# Canada             2191                 380
# ...                 ...                 ...
# Liechtenstein         1                   1
# Lesotho               1                   0
# Gabon                 1                   0
# Saint Lucia           1                   0
# Nauru                 1                   1
#
# [183 rows x 2 columns]

# %%
Angular_df.rename(columns={'Country':'NumRespondents', 'WebframeWorkedWith':'NumKnowsAngular'},inplace=True)
Angular_df
# Out:
#                 NumRespondents  NumKnowsAngular
# United States            12469             2453
# India                     8403             2052
# United Kingdom            3896              649
# Germany                   3890              797
# Canada                    2191              380
# ...                        ...              ...
# Liechtenstein                1                1
# Lesotho                      1                0
# Gabon                        1                0
# Saint Lucia                  1                0
# Nauru                        1                1
#
# [183 rows x 2 columns]

# %%
Angular_df['PctKnowsPython']=(Angular_df['NumKnowsAngular']/Angular_df['NumRespondents'])*100
Angular_df
# Out:
#                 NumRespondents  NumKnowsAngular  PctKnowsPython
# United States            12469             2453       19.672789
# India                     8403             2052       24.419850
# United Kingdom            3896              649       16.658111
# Germany                   3890              797       20.488432
# Canada                    2191              380       17.343679
# ...                        ...              ...             ...
# Liechtenstein                1                1      100.000000
# Lesotho                      1                0        0.000000
# Gabon                        1                0        0.000000
# Saint Lucia                  1                0        0.000000
# Nauru                        1                1      100.000000
#
# [183 rows x 3 columns]

# %%
Angular_df.sort_values(by='PctKnowsPython', ascending=False, inplace=True)

# %%
Angular_df.head(50)
# Out:
#                                            NumRespondents  NumKnowsAngular  \
# Nauru                                                   1                1
# Liechtenstein                                           1                1
# Grenada                                                 1                1
# Chad                                                    1                1
# San Marino                                              2                1
# Djibouti                                                2                1
# Ecuador                                                49               22
# Madagascar                                             21                9
# Lao People's Democratic Republic                        7                3
# Cuba                                                   22                9
# Dominican Republic                                     72               29
# ...

# %%
Angular_df.loc['Japan']
# Out:
# NumRespondents     297.000000
# NumKnowsAngular     47.000000
# PctKnowsPython      15.824916
# Name: Japan, dtype: float64

# %%
df['UndergradMajor'].value_counts()
# Out:
# Computer science, computer engineering, or software engineering                   31582
# Another engineering discipline (such as civil, electrical, mechanical, etc.)       4754
# Information systems, information technology, or system administration              4071
# A natural science (such as biology, chemistry, physics, etc.)                      2205
# Mathematics or statistics                                                          1849
# Web development or web design                                                      1789
# A business discipline (such as accounting, finance, marketing, etc.)               1375
# A humanities discipline (such as literature, history, philosophy, etc.)            1007
# A social science (such as anthropology, psychology, political science, etc.)        933
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)      725
# I never declared a major                                                            453
# ...

# %%
country_study_CSE = country_grp['UndergradMajor'].apply(lambda x:x.str.contains('Computer science, computer engineering, or software engineering').sum())
country_study_CSE
# Out:
# Country
# Afghanistan                              30
# Albania                                  25
# Algeria                                  40
# Andorra                                   1
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     30
# Viet Nam                                123
# Yemen                                     1
# Zambia                                   13
# Zimbabwe                                 12
# Name: UndergradMajor, Length: 183, dtype: int64

# %%
country_respondents
# Out:
# United States     12469
# India              8403
# United Kingdom     3896
# Germany            3890
# Canada             2191
#                   ...
# Liechtenstein         1
# Lesotho               1
# Gabon                 1
# Saint Lucia           1
# Nauru                 1
# Name: Country, Length: 183, dtype: int64

# %%
CSE_df = pd.concat([country_respondents, country_study_CSE], axis='columns', sort=False)
CSE_df
# Out:
#                 Country  UndergradMajor
# United States     12469            5997
# India              8403            4545
# United Kingdom     3896            1776
# Germany            3890            1925
# Canada             2191            1214
# ...                 ...             ...
# Liechtenstein         1               1
# Lesotho               1               0
# Gabon                 1               0
# Saint Lucia           1               1
# Nauru                 1               0
#
# [183 rows x 2 columns]

# %%
CSE_df.rename(columns={'Country':'NumRespondents', 'UndergradMajor':'Degreepassedwith'},inplace=True)
CSE_df
# Out:
#                 NumRespondents  Degreepassedwith
# United States            12469              5997
# India                     8403              4545
# United Kingdom            3896              1776
# Germany                   3890              1925
# Canada                    2191              1214
# ...                        ...               ...
# Liechtenstein                1                 1
# Lesotho                      1                 0
# Gabon                        1                 0
# Saint Lucia                  1                 1
# Nauru                        1                 0
#
# [183 rows x 2 columns]

# %%
CSE_df['PctKnowsCSE']=(CSE_df['Degreepassedwith']/CSE_df['NumRespondents'])*100
CSE_df
# Out:
#                 NumRespondents  Degreepassedwith  PctKnowsCSE
# United States            12469              5997    48.095276
# India                     8403              4545    54.087826
# United Kingdom            3896              1776    45.585216
# Germany                   3890              1925    49.485861
# Canada                    2191              1214    55.408489
# ...                        ...               ...          ...
# Liechtenstein                1                 1   100.000000
# Lesotho                      1                 0     0.000000
# Gabon                        1                 0     0.000000
# Saint Lucia                  1                 1   100.000000
# Nauru                        1                 0     0.000000
#
# [183 rows x 3 columns]

# %%
CSE_df.sort_values(by='PctKnowsCSE', ascending=False, inplace=True)
CSE_df.head(50)
# Out:
#                                            NumRespondents  Degreepassedwith  \
# Saint Lucia                                             1                 1
# Liechtenstein                                           1                 1
# Fiji                                                    1                 1
# North Korea                                             1                 1
# Democratic Republic of the Congo                        7                 6
# Bahrain                                                 9                 7
# Cuba                                                   22                17
# Kosovo                                                 34                26
# Isle of Man                                             8                 6
# Guatemala                                              49                36
# Mozambique                                              7                 5
# ...

# %%
#2 October 2021
import pandas as pd
na_vals=['NA','missing']
df = pd.read_csv('survey_results_public.csv', index_col= 'Respondent', na_values=na_vals)

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year',0,inplace=True)

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1     36
# 2      7
# 3      4
# 4      7
# 5     15
# 6      6
# 7      6
# 8     17
# 9      6
# 10     8
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].replace('More than 50 years',51,inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 12.709052770265584

# %%
df['YearsCode'].median()
# Out:
# 10.0
